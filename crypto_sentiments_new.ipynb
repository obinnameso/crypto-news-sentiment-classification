# %% [markdown]
# ### test

# %%
import numpy as np                                          #For statistics, array creation and manipulation
import pandas as pd                                         #For data loading and data manipulation
import seaborn as sns                                       #For data visualization
from wordcloud import WordCloud                             #For visualizing the summarized textual data
import matplotlib.pyplot as plt                             #For data visualization - %matplotlib below is a magic command to render matplotlib in jupyter
# %matplotlib inline

import nltk                                                 #For natural language processing
from nltk.corpus import stopwords                           #For stopwords processing
from nltk.tokenize import TreebankWordTokenizer             #For splitting sentences into words
from nltk import SnowballStemmer, PorterStemmer
from nltk.stem import WordNetLemmatizer                     #For reducing words to its base form
from sklearn.feature_extraction.text import CountVectorizer #For mapping/converting words into real numbers
from sklearn.model_selection import train_test_split        #For splitting the dataset into train and test
from textblob import TextBlob

from sklearn.metrics import classification_report, f1_score, accuracy_score #For evaluating model preformance
import string
import re                                               #For data cleaning to remove/replace unwanted patterns
import pickle

# Download NLTK data (run this once)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')

pd.set_option('max_colwidth', 800)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
df = pd.read_csv("/content/articlesData.csv")

# %%
df.shape
# Out:
# (26751, 12)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '_id', 'id', 'Domain', 'Source', 'Title', 'Date', 'Slug',
#        'Currencies', 'URL', 'Created_at', 'Language'],
#       dtype='object')

# %%
## select only english news headlines
df_n = df[df['Language'] == 'en']
df_n = df_n[:5000]  ## select first 5000 rows

# %%
df_n.reset_index()
# Out:
#       index  Unnamed: 0                       _id        id  \
# 0        20          20  6370cd069a9af76fe9539f46  16884976
# 1        21          21  6370cd069a9af76fe9539f47  16884983
# 2        22          22  6370cd069a9af76fe9539f48  16884964
# 3        23          23  6370cd069a9af76fe9539f49  16884948
# 4        24          24  6370cd069a9af76fe9539f4a  16884786
# ...     ...         ...                       ...       ...
# 4995   5741        5741  63910280b73c753d0c615b7d  17094996
# 4996   5742        5742  63910280b73c753d0c615b7e  17094954
# 4997   5743        5743  63910280b73c753d0c615b7f  17094961
# 4998   5744        5744  63910280b73c753d0c615b80  17094963
# 4999   5745        5745  63910987a331bb6279765ac3  17095066
#
#                   Domain           Source  \
# 0                u.today          U.Today
# 1         beincrypto.com       BeInCrypto
# 2        cryptoglobe.com      CryptoGlobe
# 3          dailyhodl.com   The Daily Hodl
# 4                u.today          U.Today
# ...                  ...              ...
# 4995         youtube.com  The Crypto Lark
# 4996   cointelegraph.com    CoinTelegraph
# 4997  theblockcrypto.com        The Block
# 4998       dailyhodl.com   The Daily Hodl
# 4999     cryptoslate.com      CryptoSlate
#
#                                                                                                                     Title  \
# 0                                                            Binance CEO Says Why You Should Avoid Exchanges That Do This
# 1                                                                               Bitcoin (BTC) Miners Sell Most in 5 Years
# 2                                       Binance CEO: Deal To Acquire FTX.com ‘Did Not Make Sense From a Number of Fronts’
# 3         Top Crypto Strategist Warns Dogecoin and Polygon Holders, Says DOGE and MATIC Could Witness Drastic Corrections
# 4                                                                         Shiba Inu Returns to Bottom Again, What's Next?
# ...                                                                                                                   ...
# 4995                                                                                         Only 7.9% Think Bitcoin Can…
# 4996                                      Crypto consumer protection, proof of reserves bills introduced into US Congress
# 4997                                                Signature Bank adopts caps to reduce concentration of crypto deposits
# 4998  Michael Saylor Says SEC Should Shut Down XRP, Ethereum, Solana and Other Altcoins for Being Unregistered Securities
# 4999      CryptoSlate Wrapped Daily: Binance auditor confirms reserves, 3AC founders subpoenaed, and Crypto Twitter drama
#
#                       Date  \
# 0     2022-11-13T10:31:00Z
# 1     2022-11-13T10:26:03Z
# 2     2022-11-13T10:20:00Z
# 3     2022-11-13T10:15:11Z
# 4     2022-11-13T10:00:00Z
# ...                    ...
# 4995  2022-12-07T21:00:07Z
# 4996  2022-12-07T21:00:00Z
# 4997  2022-12-07T20:58:22Z
# 4998  2022-12-07T20:55:37Z
# 4999  2022-12-07T21:30:58Z
#
#                                                                                                                    Slug  \
# 0                                                          Binance-CEO-Says-Why-You-Should-Avoid-Exchanges-That-Do-This
# 1                                                                               Bitcoin-BTC-Miners-Sell-Most-in-5-Years
# 2                                         Binance-CEO-Deal-To-Acquire-FTXcom-Did-Not-Make-Sense-From-a-Number-of-Fronts
# 3        Top-Crypto-Strategist-Warns-Dogecoin-and-Polygon-Holders-Says-DOGE-and-MATIC-Could-Witness-Drastic-Corrections
# 4                                                                          Shiba-Inu-Returns-to-Bottom-Again-Whats-Next
# ...                                                                                                                 ...
# 4995                                                                                          Only-79-Think-Bitcoin-Can
# 4996                                     Crypto-consumer-protection-proof-of-reserves-bills-introduced-into-US-Congress
# 4997                                              Signature-Bank-adopts-caps-to-reduce-concentration-of-crypto-deposits
# 4998  Michael-Saylor-Says-SEC-Should-Shut-Down-XRP-Ethereum-Solana-and-Other-Altcoins-for-Being-Unregistered-Securities
# 4999       CryptoSlate-Wrapped-Daily-Binance-auditor-confirms-reserves-3AC-founders-subpoenaed-and-Crypto-Twitter-drama
#
#                         Currencies  \
# 0                              NaN
# 1                         Bitcoin
# 2                             FTX
# 3        Bitcoin Dogecoin Polygon
# 4                       Shiba Inu
# ...                            ...
# 4995                      Bitcoin
# 4996                           NaN
# 4997                           NaN
# 4998  Bitcoin Ethereum XRP Solana
# 4999              Bitcoin Polygon
#
#                                                                                                                                                           URL  \
# 0                                                          https://cryptopanic.com/news/16884976/Binance-CEO-Says-Why-You-Should-Avoid-Exchanges-That-Do-This
# 1                                                                               https://cryptopanic.com/news/16884983/Bitcoin-BTC-Miners-Sell-Most-in-5-Years
# 2                                         https://cryptopanic.com/news/16884964/Binance-CEO-Deal-To-Acquire-FTXcom-Did-Not-Make-Sense-From-a-Number-of-Fronts
# 3        https://cryptopanic.com/news/16884948/Top-Crypto-Strategist-Warns-Dogecoin-and-Polygon-Holders-Says-DOGE-and-MATIC-Could-Witness-Drastic-Corrections
# 4                                                                          https://cryptopanic.com/news/16884786/Shiba-Inu-Returns-to-Bottom-Again-Whats-Next
# ...                                                                                                                                                       ...
# 4995                                                                                          https://cryptopanic.com/news/17094996/Only-79-Think-Bitcoin-Can
# 4996                                     https://cryptopanic.com/news/17094954/Crypto-consumer-protection-proof-of-reserves-bills-introduced-into-US-Congress
# 4997                                              https://cryptopanic.com/news/17094961/Signature-Bank-adopts-caps-to-reduce-concentration-of-crypto-deposits
# 4998  https://cryptopanic.com/news/17094963/Michael-Saylor-Says-SEC-Should-Shut-Down-XRP-Ethereum-Solana-and-Other-Altcoins-for-Being-Unregistered-Securities
# 4999       https://cryptopanic.com/news/17095066/CryptoSlate-Wrapped-Daily-Binance-auditor-confirms-reserves-3AC-founders-subpoenaed-and-Crypto-Twitter-drama
#
#                 Created_at Language
# 0     2022-11-13T10:31:00Z       en
# 1     2022-11-13T10:26:03Z       en
# 2     2022-11-13T10:20:00Z       en
# 3     2022-11-13T10:15:11Z       en
# 4     2022-11-13T10:00:00Z       en
# ...                    ...      ...
# 4995  2022-12-07T21:00:07Z       en
# 4996  2022-12-07T21:00:00Z       en
# 4997  2022-12-07T20:58:22Z       en
# 4998  2022-12-07T20:55:37Z       en
# 4999  2022-12-07T21:30:58Z       en
#
# [5000 rows x 13 columns]

# %%
df_n.shape
# Out:
# (5000, 12)

# %%
df_n.Source.nunique()
# Out:
# 64

# %%
df_n.Currencies.nunique()
# Out:
# 410

# %%
df_n.Currencies.unique()
# Out:
# array([nan, 'Bitcoin ', 'FTX ', 'Bitcoin Dogecoin Polygon ', 'Shiba Inu ',
#        'Bitcoin Solana ', 'Tether Huobi ', 'Ethereum Gate ',
#        'Bitcoin Ethereum ', 'TRON ', 'Ethereum Huobi ', 'Bitcoin FTX ',
#        'Dogecoin ', 'XRP ', 'Solana ', 'Ethereum ', 'Bitcoin Cash ',
#        'BNB Chain OEC Binance Coin ', 'Helium ', 'Ethereum FTX ',
#        'Huobi ', 'Cardano ', 'Ethereum ApeCoin ', 'Ethereum Cardano FTX ',
#        'Polygon ', 'Uniswap ', 'Bitcoin Ethereum FTX ', 'Cronos ',
#        'OEC Binance Coin ETHDOWN ETHUP BNB Heco-Peg Binance Coin ',
#        'Bitcoin Bitcoin Cash Wrapped Bitcoin (Sollet) Cronos ',
#        'Chainlink FTX ', 'MCO Cronos Wrapped CRO MCO ',
#        'Bitcoin Dogecoin ', 'Chiliz FTX ', 'Bitcoin Cronos ',
#        'Bitcoin Ethereum Solana ', 'Axie Infinity ', 'Huobi FTX ',
#        'Market Cap Bitcoin ', 'Cronos Terra Luna Classic FTX ',
#        'Cardano FTX ', 'Terra Luna Classic ', 'Maker ',
#        'Ethereum BNB FTX ', 'Hedera ', 'Ethereum XRP Cardano ',
#        'Avalanche ', 'Trust Wallet ', 'Bitcoin Bitcoin Cash FTX ',
#        'Bitcoin Quant ', 'Bitcoin Litecoin ', 'Quant ',
#        'Ethereum Polygon ', 'Ethereum Uniswap FTX ', 'Flow FTX ',
#        'Trust Wallet FTX ', 'Cosmos Hub ', 'Polkadot ',
#        'Bitcoin Ethereum Polygon ', 'Ethereum Uniswap ', 'Chiliz ',
#        'Bitcoin Ethereum Uniswap PancakeSwap ', 'Bitcoin Trust Wallet ',
#        'Arweave ', 'XRP Flow ', 'Bitcoin Ethereum USD Coin PAX Gold ',
#        'Bitcoin Ethereum XRP ', 'Bitcoin Zcash FTX ', 'Dai ',
#        'Cronos FTX ', 'Bitcoin Trust Wallet FTX ', 'GMX FTX ',
#        'Bitcoin Ethereum Tether Dai Uniswap ', 'KuCoin ',
#        'Ethereum Dai FTX ', 'Bitcoin Chain Trust Wallet PAX Gold ',
#        'Tether Dai ', 'TRON USDD ', 'Ethereum Algorand ',
#        'Monero Zcash Dash ', 'The Sandbox Decentraland ',
#        'Ethereum PAX Gold FTX ', 'Ethereum BNB Dai FTX ', '1inch ',
#        'Polkadot Chain ', 'Stacks FTX ', 'BNB PancakeSwap ',
#        'Bitcoin Ethereum Dogecoin Chainlink FTX ',
#        'Bitcoin Ethereum XRP TRON FTX ', 'ApeCoin ', 'Ethereum Solana ',
#        'Ethereum Cosmos Hub ', 'Ethereum Polygon FTX ', 'USD Coin ',
#        'Bitcoin Ethereum Tether Binance USD XRP FTX ', 'Polygon Chain ',
#        'Bitcoin Ethereum Chiliz ', 'Bitcoin Ethereum XRP Huobi FTX ',
#        'USD Coin Binance USD ', 'Bitcoin Ethereum Dash ', 'Solana FTX ',
#        'USD Coin Binance USD FTX ', 'Shiba Inu FTX ', 'Polkadot Kusama ',
#        'Chainlink ', 'Algorand ', 'Dogecoin Shiba Inu ', 'Dogecoin FTX ',
#        'NEXO ', 'Aave Gemini Dollar ', 'Ethereum Tether ',
#        'Ethereum XRP FTX ', 'Tether Dogecoin ',
#        'Bitcoin Ethereum XRP Dogecoin Cardano Polygon Polkadot Uniswap Litecoin OEC Binance Coin ',
#        'USD Coin FTX ', 'Ethereum Polygon Shiba Inu KuCoin ', 'Chain ',
#        'TerraClassicUSD ', 'Tether ', 'Bitcoin TRON Flow ',
#        'Bitcoin Ethereum Dogecoin FTX ', 'Bitcoin Ethereum Solana FTX ',
#        'Ethereum Chain ', 'BNB ', 'VeChain ', 'Market Cap FTX ',
#        'The Open Network ', 'Tether USD Coin ',
#        'Tether USD Coin Solana FTX ', 'Stellar ',
#        'Ethereum NEXO Ethereum Name Service ', 'Bitcoin Gate ',
#        'Bitcoin Ethereum Tether ', 'Bitcoin Terra Luna Classic FTX ',
#        'Bitcoin Tether ', 'Tether USD Coin Solana ', 'Bitcoin XRP ',
#        'OEC Binance Coin ',
#        'Bitcoin Ethereum BNB Polkadot Uniswap Chiliz Chain Trust Wallet PancakeSwap GMX FTX ',
#        'Ethereum Dogecoin Chiliz FTX ', 'USD Coin Solana ',
#        'Chiliz Trust Wallet Dash ', 'Lido DAO ', 'Monero Chain Zcash ',
#        'Bitcoin Ethereum Trust Wallet ', 'TRON FTX ',
#        'Bitcoin Dogecoin Solana ',
#        'Bitcoin Cash Quant NEAR Protocol Flow ', 'Litecoin ',
#        'Market Cap Bitcoin FTX ', 'Avalanche Chainlink Flow KuCoin ',
#        'Decentraland Huobi ', 'Ethereum Lido DAO ',
#        'Bitcoin Tether BNB Shiba Inu KuCoin FTX ',
#        'Bitcoin Bitcoin Cash ', 'Bitcoin Ethereum Chiliz Trust Wallet ',
#        'Ethereum Tether Solana Chain ',
#        'Bitcoin BNB LEO Token Chiliz Trust Wallet ',
#        'Bitcoin Ethereum XRP Dogecoin Cardano Polygon Polkadot Litecoin Uniswap OEC Binance Coin ',
#        'Tether Solana ', 'XRP Chainlink ',
#        'Bitcoin Ethereum BNB Polygon Cosmos Hub OEC Binance Coin ',
#        'Bitcoin Ethereum Dogecoin ', 'Ethereum Cardano ',
#        'TRON Bitcoin Cash NEAR Protocol ', 'Bitcoin Dogecoin Shiba Inu ',
#        'Algorand ApeCoin ', 'Bitcoin Cash NEAR Protocol FTX ',
#        'Bitcoin Cardano ', 'Ethereum XRP ',
#        'Ethereum BNB OEC Binance Coin ',
#        'Bitcoin Bitcoin Cash Wrapped Bitcoin (Sollet) ', 'Aave ',
#        'Uniswap Aave ', 'Bitcoin Quant Chiliz Trust Wallet ',
#        'Bitcoin Ethereum XRP FTX ', 'Mina Protocol ', 'Celsius Network ',
#        'Bitcoin Ethereum NEM ', 'NEAR Protocol FTX ',
#        'Ethereum Shiba Inu ', 'Ethereum Dogecoin ', 'TRON Solana ',
#        'Bitcoin Ethereum Polygon Polkadot ', 'Aptos ', 'XRP FTX ',
#        'Uniswap NEXO FTX ', 'Bitcoin The Graph ',
#        'Bitcoin Ethereum Cardano ', 'Bitcoin Ethereum Wrapped Bitcoin ',
#        'Avalanche Cosmos Hub ', 'Market Cap Litecoin Solana ',
#        'Cardano Monero ', 'Bitcoin Ethereum Cardano Dogecoin ',
#        'Bitcoin Ethereum XRP Cardano Dogecoin Polygon Polkadot OEC Binance Coin ',
#        'Flow ', 'The Sandbox ', 'Tezos ', 'Bitcoin Ethereum Huobi FTX ',
#        'TRON Huobi ', 'Bitcoin Ethereum Tether FTX ',
#        'Ethereum Solana Chainlink FTX ',
#        'Avalanche Chainlink Flow Chiliz ', 'Ethereum Aave Curve DAO ',
#        'Bitcoin Tether FTX ', 'Ethereum The Sandbox ',
#        'Bitcoin Ethereum XRP Litecoin FTX ', 'Bitcoin Ethereum BNB ',
#        'Bitcoin Litecoin FTX ', 'Polygon Solana ', 'XDC Network ',
#        'Cardano Algorand ',
#        'Bitcoin Ethereum XRP The Open Network Huobi Maker ',
#        'The Sandbox Axie Infinity ', 'Aave Curve DAO Aave [OLD] ',
#        'Litecoin Solana ', 'Aave Curve DAO ',
#        'Ethereum Cardano Polkadot Litecoin TRON ', 'Ethereum Maker ',
#        'Shiba Inu Litecoin ', 'Shiba Inu Decentraland ', 'Bitcoin Chain ',
#        'Ethereum Litecoin Solana ', 'Bitcoin Ethereum Litecoin FTX ',
#        'Bitcoin Ethereum Quant FTX ', 'Bitcoin Celsius Network ',
#        'Algorand FTX ', 'Bitcoin Ethereum Litecoin ',
#        'Bitcoin Ethereum Chainlink ', 'TRON Huobi FTX ', 'Curve DAO ',
#        'Bitcoin Solana FTX ', 'Ethereum Name Service ',
#        'Tether USD Coin FTX ', 'Bitcoin Ethereum Quant ',
#        'Litecoin Dash Curve DAO ',
#        'Market Cap Bitcoin Ethereum Litecoin Shiba Inu ',
#        'Bitcoin Ethereum Litecoin Ethereum Classic ',
#        'Bitcoin Ethereum USD Coin Ethereum Classic Aave Curve DAO Aave [OLD] ',
#        'Ethereum Polygon Solana Chain ', 'Aave Aave [OLD] ',
#        'Polygon Solana Aave ', 'Bitcoin Ethereum Cosmos Hub FTX ',
#        'Bitcoin BNB Solana ', 'Bitcoin Quant FTX ', 'Bitcoin BNB ',
#        'Ethereum Litecoin Solana Zcash Curve DAO FTX ',
#        'Bitcoin Ethereum Solana Ethereum Classic ',
#        'Bitcoin Ethereum Litecoin Solana ', 'Bitcoin Zcash ',
#        'Tether FTX ', 'Bitcoin BNB Litecoin Chainlink Chain Huobi ',
#        'EOS ', 'NEAR Protocol ', 'Bitcoin Flow ',
#        'Bitcoin Chainlink FTX ', 'Bitcoin XRP Chainlink Flow ',
#        'Bitcoin Ethereum Polkadot Chainlink FTX ',
#        'XRP Polygon Polkadot Chainlink Chiliz ', 'NEO ', 'Aave [OLD] ',
#        'Cardano Polygon ', 'Bitcoin Ethereum XRP Litecoin ', 'Klaytn ',
#        'Bitcoin XRP Solana FTX ', 'Bitcoin Litecoin Bitcoin Cash Huobi ',
#        'Bitcoin Ethereum Polkadot Litecoin ', 'Bitcoin Ethereum Chain ',
#        'Binance USD ', 'NEAR Protocol EthereumPoW ',
#        'Bitcoin Ethereum Dogecoin Litecoin ', 'BNB OEC Binance Coin ',
#        'XRP Shiba Inu ', 'Bitcoin Wrapped Bitcoin FTX ',
#        'Uniswap PancakeSwap ', 'BNB XRP Polygon OEC Binance Coin ',
#        'Bitcoin BNB OEC Binance Coin FTX ', 'Ethereum Polkadot ',
#        'BNB Dogecoin Litecoin Avalanche Cosmos Hub OEC Binance Coin ',
#        'Dash ', 'Bitcoin Ethereum USD Coin Dai Wrapped Bitcoin ',
#        'Bitcoin XRP TRON ', 'BNB Chain PancakeSwap ',
#        'OKB OKX Staked DOT1 OKX Staked DOT2 Tether ', 'BNB Dogecoin ',
#        'Bitcoin Ethereum Polygon Chainlink ',
#        'Bitcoin Ethereum Dogecoin Polygon Litecoin ', 'Avalanche FTX ',
#        'Bitcoin Ethereum BNB OEC Binance Coin ', 'BNB TRON ',
#        'Bitcoin Ethereum Huobi ', 'Ethereum XRP Litecoin ',
#        'Bitcoin BNB XRP Dogecoin Shiba Inu ',
#        'Bitcoin Dogecoin Litecoin Chainlink ApeCoin ',
#        'XRP Dogecoin Solana ', 'Bitcoin The Open Network ',
#        'Bitcoin Chainlink ', 'Market Cap NEXO ',
#        'Bitcoin Dogecoin Litecoin ', 'Bitcoin XRP Dogecoin ', 'Fantom ',
#        'Bitcoin Ethereum Bitcoin Cash ',
#        'Litecoin Chainlink ApeCoin EOS Theta Network ',
#        'Ethereum Chiliz ', 'BNB Trust Wallet ',
#        'Bitcoin Ethereum XRP Dogecoin Cardano Polygon Polkadot OEC Binance Coin ',
#        'Ethereum Dogecoin Cardano Polygon ', 'Uniswap FTX ',
#        'Flow Fantom ', 'Cardano Chainlink ', 'Terra Luna Classic Chain ',
#        'Polygon Uniswap ', 'Bitcoin Ethereum Dogecoin Polygon ',
#        'Tether USD Coin Terra Luna Classic ',
#        'Bitcoin Ethereum Dogecoin Cardano Maker Fantom ',
#        'Ethereum Polygon Solana ', 'Bitcoin XRP Stellar ', 'BNB Chain ',
#        'XRP Bitcoin Cash ', 'Bitcoin Ethereum XRP Stellar Bitcoin Cash ',
#        'Cardano Cosmos Hub ', 'KuCoin FTX ', 'Gemini Dollar ',
#        'Bitcoin Polkadot Algorand ', 'Ethereum Avalanche Hedera Fantom ',
#        'Market Cap ', 'XRP Maker ',
#        'Bitcoin BNB Litecoin Solana Avalanche KuCoin OEC Binance Coin ',
#        'Bitcoin Litecoin Aave ', 'Ethereum BitDAO ', 'Bitcoin XRP FTX ',
#        'Bitcoin Ethereum XRP Stellar ', 'Fantom FTX ', 'Ethereum Fantom ',
#        'BNB USD Coin Uniswap Chain ', 'Bitcoin Dogecoin ApeCoin ',
#        'Bitcoin BNB Litecoin ApeCoin OEC Binance Coin ',
#        'Ethereum Avalanche ', 'Ethereum Uniswap GMX ',
#        'Bitcoin Ethereum Solana Flow ', 'Ethereum Chainlink ',
#        'Bitcoin Ethereum Polkadot Avalanche Cosmos Hub ',
#        'Bitcoin Polygon GMX ', 'Bitcoin Ethereum BNB XRP Dogecoin ',
#        'BNB Litecoin ApeCoin Chain PancakeSwap Aptos ',
#        'Polygon The Graph ', 'Uniswap GMX FTX ',
#        'Bitcoin Ethereum Dogecoin Polygon Litecoin Shiba Inu ',
#        'Bitcoin Ethereum BNB Dogecoin FTX ',
#        'Bitcoin Ethereum XRP Ethereum Classic Stellar Bitcoin Cash ',
#        'Ethereum Solana Flow ', 'Polygon Quant ',
#        'Bitcoin Ethereum Fantom ', 'Bitcoin TRON Huobi USDD ',
#        'Bitcoin Dogecoin Curve DAO ', 'Ethereum Dogecoin Shiba Inu ',
#        'BNB Polygon Chainlink OEC Binance Coin ',
#        'Dogecoin Huobi Fantom ', 'Bitcoin Ethereum ApeCoin ',
#        'Bitcoin Cash Curve DAO ', 'BNB OEC Binance Coin FTX ',
#        'Quant FTX ', 'The Graph ', 'BNB Polygon Chainlink ',
#        'Tether TRON ', 'BNB Dogecoin Cardano ',
#        'Ethereum Cardano Polkadot ', 'Ethereum Polygon Litecoin Fantom ',
#        'Bitcoin Polygon ', 'Ethereum Cardano Polkadot Cosmos Hub ',
#        'Ethereum Rocket Pool ',
#        'Ethereum Dogecoin Shiba Inu Solana Uniswap Chainlink FTX ',
#        'Bitcoin Solana Chainlink ',
#        'Bitcoin Ethereum Avalanche Chainlink ',
#        'Market Cap Tether XRP Cardano TRON Cosmos Hub ', 'Solana Aptos ',
#        'Bitcoin ApeCoin Trust Wallet Aave Aave [OLD] ',
#        'Ethereum Aave Aave [OLD] ', 'Bitcoin Axie Infinity ',
#        'Ethereum XRP Chainlink ', 'PancakeSwap ',
#        'Bitcoin Dogecoin Axie Infinity ', 'Bitcoin Axie Infinity Chiliz ',
#        'Bitcoin KuCoin FTX ', 'Algorand Axie Infinity Chiliz ',
#        'Ethereum Polygon Polkadot Avalanche Cosmos Hub ',
#        'Market Cap Litecoin ', 'Bitcoin BNB Cardano ',
#        'BNB Chain PancakeSwap OEC Binance Coin ',
#        'Bitcoin Ethereum Axie Infinity ', 'XRP Dogecoin ',
#        'Bitcoin Polkadot ', 'Cardano Litecoin Avalanche Flow ',
#        'Tether Tether Gold ', 'Bitcoin OEC Binance Coin ',
#        'Bitcoin XRP Shiba Inu ', 'Bitcoin Ethereum BNB Dogecoin Cardano ',
#        'Polygon Chainlink ', 'Bitcoin Dogecoin Cardano Polygon ',
#        'Bitcoin Ethereum Shiba Inu Decentraland ',
#        'Bitcoin Tether USD Coin Flow ', 'Decentraland ', 'Sushi ',
#        'Bitcoin Stellar ', 'Dogecoin Cardano ', 'ImmutableX ',
#        'MultiversX (Elrond) ',
#        'Bitcoin Ethereum Tether TRON Avalanche Chainlink ',
#        'Bitcoin BNB Dogecoin ', 'XRP Dogecoin Cardano Polygon ',
#        'Bitcoin Ethereum XRP Solana '], dtype=object)

# %%
df_n.Title.head()
# Out:
# 20                                                       Binance CEO Says Why You Should Avoid Exchanges That Do This
# 21                                                                          Bitcoin (BTC) Miners Sell Most in 5 Years
# 22                                  Binance CEO: Deal To Acquire FTX.com ‘Did Not Make Sense From a Number of Fronts’
# 23    Top Crypto Strategist Warns Dogecoin and Polygon Holders, Says DOGE and MATIC Could Witness Drastic Corrections
# 24                                                                    Shiba Inu Returns to Bottom Again, What's Next?
# Name: Title, dtype: object

# %%
# df_n['Title'] = df_n['Title'].fillna('').astype(str)

# %%
df_n.isna().sum()
# Out:
# Unnamed: 0       0
# _id              0
# id               0
# Domain           0
# Source           0
# Title            0
# Date             0
# Slug             0
# Currencies    1771
# URL              0
# Created_at       0
# Language         0
# dtype: int64

# %% [markdown]
# ### Clean and tokenize the data

# %%
def preprocess_text(text):
    # Lowercasing
    text = text.lower()
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove symbols (except alphanumeric)
    text = re.sub(r'[^\w]', ' ', text)
    # Remove numbers
    text = ''.join([i for i in text if not i.isdigit()])
    ## remove single characters eg 'k'
    text = re.sub(r"\b\w\b", "", text)
    # Remove extra whitespace
    text = ' '.join(text.split())
    # Remove special characters
    text = re.sub(r'\W', ' ', text)
    # Tokenization
    tokens = nltk.word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    # Lemmatization
    # lemmatizer = WordNetLemmatizer()
    # tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return tokens

def preprocess_dataframe(df, text_column, new_column):
    df[new_column] = df[text_column].apply(preprocess_text)
    return df

# %%
df1 = preprocess_dataframe(df_n.copy(), 'Title','clean_title')
df1.head(1)
# Out:
#     Unnamed: 0                       _id        id   Domain   Source  \
# 20          20  6370cd069a9af76fe9539f46  16884976  u.today  U.Today
#
#                                                            Title  \
# 20  Binance CEO Says Why You Should Avoid Exchanges That Do This
#
#                     Date  \
# 20  2022-11-13T10:31:00Z
#
#                                                             Slug Currencies  \
# 20  Binance-CEO-Says-Why-You-Should-Avoid-Exchanges-That-Do-This        NaN
#
#                                                                                                    URL  \
# 20  https://cryptopanic.com/news/16884976/Binance-CEO-Says-Why-You-Should-Avoid-Exchanges-That-Do-This
#
#               Created_at Language                             clean_title
# 20  2022-11-13T10:31:00Z       en  [binance, ceo, says, avoid, exchanges]

# %%
def join_tokens(tokens):
    # tokens contain a list of words
    return ' '.join(tokens)

df1['clean_title'] = df1['clean_title'].apply(join_tokens)
df1.head(1)
# Out:
#     Unnamed: 0                       _id        id   Domain   Source  \
# 20          20  6370cd069a9af76fe9539f46  16884976  u.today  U.Today
#
#                                                            Title  \
# 20  Binance CEO Says Why You Should Avoid Exchanges That Do This
#
#                     Date  \
# 20  2022-11-13T10:31:00Z
#
#                                                             Slug Currencies  \
# 20  Binance-CEO-Says-Why-You-Should-Avoid-Exchanges-That-Do-This        NaN
#
#                                                                                                    URL  \
# 20  https://cryptopanic.com/news/16884976/Binance-CEO-Says-Why-You-Should-Avoid-Exchanges-That-Do-This
#
#               Created_at Language                       clean_title
# 20  2022-11-13T10:31:00Z       en  binance ceo says avoid exchanges

# %% [markdown]
# to do
# 1. assign sentiments to the rows .. use only 5k rows **
# 2. train distilbert model **
# 3. test using train_test split **
# 4. do streamlit

# %%
## use textblob to assign sentiments to headlines
from textblob import TextBlob

def assign_sentiment_category(df, column_name):

    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' not found in the DataFrame.")

    def categorize_sentiment(text):
        polarity = TextBlob(text).sentiment.polarity
        if polarity > 0:
            return "Positive"
        elif polarity < 0:
            return "Negative"
        else:
            return "Neutral"

    # Apply categorization
    df['sentiment'] = df[column_name].apply(categorize_sentiment)
    return df

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', '_id', 'id', 'Domain', 'Source', 'Title', 'Date', 'Slug',
#        'Currencies', 'URL', 'Created_at', 'Language', 'clean_title'],
#       dtype='object')

# %%
df1 = df1[['clean_title']] ## reduce dataframe to only needed column before calling the function

# %%
df1 = assign_sentiment_category(df1, 'clean_title')
# print(df)

# %%
df1.head()
# Out:
#                                                                                                clean_title  \
# 20                                                                        binance ceo says avoid exchanges
# 21                                                                           bitcoin btc miners sell years
# 22                                                binance ceo deal acquire ftxcom make sense number fronts
# 23  top crypto strategist warns dogecoin polygon holders says doge matic could witness drastic corrections
# 24                                                                     shiba inu returns bottom whats next
#
#    sentiment
# 20   Neutral
# 21   Neutral
# 22   Neutral
# 23  Positive
# 24   Neutral

# %%
df1.sentiment.value_counts()
# Out:
# sentiment
# Neutral     3083
# Positive    1192
# Negative     725
# Name: count, dtype: int64

# %%
df1.to_csv('sentiment_data.csv', index= False)

# %% [markdown]
# ### train the distilbert model for sentiment classification

# %%
# !pip install transformers torch accelerate datasets -U --quiet ## might be needed just once if errors are encountered
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 18.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
df1 = pd.read_csv('/content/sentiment_data.csv')
df1.head(1)
# Out:
#                         clean_title sentiment
# 0  binance ceo says avoid exchanges   Neutral

# %%
import os
os.environ["WANDB_DISABLED"] = "true"

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, Trainer, TrainingArguments
from datasets import Dataset
import torch

# Map sentiment to numeric labels
label_map = {'Negative': 0, 'Neutral': 1, 'Positive': 2}
df1['Label'] = df1['sentiment'].map(label_map)

# Split dataset into train, validation, and test sets
train_texts, temp_texts, train_labels, temp_labels = train_test_split(
    df1['clean_title'], df1['Label'], test_size=0.3, random_state=42
)
val_texts, test_texts, val_labels, test_labels = train_test_split(
    temp_texts, temp_labels, test_size=0.5, random_state=42
)

# Convert to Hugging Face Dataset
train_data = Dataset.from_dict({'text': train_texts.tolist(), 'label': train_labels.tolist()})
val_data = Dataset.from_dict({'text': val_texts.tolist(), 'label': val_labels.tolist()})
test_data = Dataset.from_dict({'text': test_texts.tolist(), 'label': test_labels.tolist()})

# Load tokenizer and model
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
model = DistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=3)

# Tokenize dataset
def tokenize_function(examples):
    return tokenizer(examples['text'], padding="max_length", truncation=True)

train_data = train_data.map(tokenize_function, batched=True)
val_data = val_data.map(tokenize_function, batched=True)
test_data = test_data.map(tokenize_function, batched=True)

# Set format for PyTorch
train_data.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
val_data.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
test_data.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',          # output directory
    evaluation_strategy="epoch",    # evaluation strategy
    learning_rate=2e-5,             # learning rate
    per_device_train_batch_size=8,  # batch size for training
    per_device_eval_batch_size=8,   # batch size for evaluation
    num_train_epochs=3,             # number of epochs
    weight_decay=0.01,              # weight decay
    save_strategy="epoch",          # save model after each epoch
    logging_dir='./logs',           # directory for logs
    logging_steps=10,
    load_best_model_at_end=True,    # load best model at the end of training
)

# Define trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_data,
    eval_dataset=val_data,
    tokenizer=tokenizer,
)

# Train the model
trainer.train()

# Save the model
model.save_pretrained('./sentiment_model')
tokenizer.save_pretrained('./sentiment_model')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/3500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/750 [00:00<?, ? examples/s]
# Map:   0%|          | 0/750 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# <ipython-input-6-fe213bf04ae3>:57: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='1314' max='1314' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1314/1314 08:56, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.520700</td>
#       <td>0.478415</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.189900</td>
#       <td>0.418196</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.266000</td>
#       <td>0.413995</td>
#     </tr>
#   </tbody>
# </table><p>
# ('./sentiment_model/tokenizer_config.json',
#  './sentiment_model/special_tokens_map.json',
#  './sentiment_model/vocab.txt',
#  './sentiment_model/added_tokens.json')

# %% [markdown]
# ### Evauation

# %%
def evaluate_test_set(model, tokenizer, test_data):
    """
    Evaluate the model on the test dataset and return classification metrics.

    Args:
        model: Trained DistilBERT model.
        tokenizer: Tokenizer used for the model.
        test_data: Dataset to evaluate on.

    Returns:
        dict: Classification report including precision, recall, and F1-score.
    """
    # Determine device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)

    # Make predictions
    test_texts = test_data['text']
    test_labels = test_data['label']
    predictions = []

    for text in test_texts:
        # Tokenize and move input tensors to the appropriate device
        inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True).to(device)
        outputs = model(**inputs)
        pred = torch.argmax(outputs.logits, dim=1).item()
        predictions.append(pred)

    # Generate classification report
    report = classification_report(test_labels, predictions, target_names=label_map.keys())
    return report

# %%
# Run evaluation
evaluation_report = evaluate_test_set(model, tokenizer, test_data)
print(evaluation_report)
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.78      0.66      0.71       112
#      Neutral       0.92      0.96      0.94       480
#     Positive       0.91      0.87      0.89       158
#
#     accuracy                           0.90       750
#    macro avg       0.87      0.83      0.85       750
# weighted avg       0.90      0.90      0.90       750
